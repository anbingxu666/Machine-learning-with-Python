# %% [markdown]
# # 一、手写数字降噪

# %% [markdown]
# ### 加载digits数据集

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# %%
data = load_digits()
X = data.data
y = data.target

# %%
X.shape
# Out:
# (1797, 64)

# %%
y.shape
# Out:
# (1797,)

# %% [markdown]
# ### 编造一个噪音

# %%
X_noisy = X + np.random.normal(0,4,size=X.shape)

# %% [markdown]
# ### 制作数据

# %%
X_plot = X_nosiy[y==0,:][:10] #之所以不写在 循环里 是因为可以为vstack创建一个标准的形状 为后序循环操作打下基础
for i in range(1,10):
    X_temp_yi = X_nosiy[y==i,:][:10]
    X_plot = np.vstack([X_plot,X_temp_yi])

# %% [markdown]
# ### 可视化函数·

# %%
def plot_digits(data):
    fig, axes = plt.subplots(10, 10, figsize=(10, 10),
                             subplot_kw={'xticks':[], 'yticks':[]},
    gridspec_kw=dict(hspace=0.1, wspace=0.1)) 
    for i, ax in enumerate(axes.flat):
        ax.imshow(data[i].reshape(8, 8),
                  cmap='binary', interpolation='nearest',
                  clim=(0, 16))

    plt.show()

# %%
plot_digits(X_plot)

# %% [markdown]
# ### 通过降维 丢失某些特征（同时也会丢失噪音）来进行降噪

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(0.5)
pca.fit(X_plot)
X_dec = pca.transform(X_plot)
X_inv = pca.inverse_transform(X_dec)

# %%
plot_digits(X_inv)

# %% [markdown]
# ### 由上图可见 清晰了不少！！！！

# %% [markdown]
# # 二、自己编造特征集 降噪

# %%
X = np.empty((100, 2))
X[:,0] = np.random.uniform(0., 100., size=100)
X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0, 5, size=100)

# %%
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
pca = PCA(n_components=1)
pca.fit(X)
X_reduction = pca.transform(X)
X_restore = pca.inverse_transform(X_reduction)

# %%
plt.scatter(X_restore[:,0], X_restore[:,1])
plt.show()
